# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("/content/final_data-20251015T214353Z-1-001.zip")
df.head()

# %%
# Out:
#    Unnamed: 0                                    STATION_NAME       CITY  \
# 0           0                                Anchorage Museum  Anchorage
# 1           1                               Anchorage Point S  Anchorage
# 2           2                    EasyPark Susitna Parking Lot  Anchorage
# 3           3  49th State Brewing Company - Tesla Destination  Anchorage
# 4           4                                  Avis Anchorage  Anchorage
#
#         STREET_ADDRESS   LATITUDE   LONGITUDE EV_CONNECTOR_TYPES  \
# 0             625 C St  61.215712 -149.884840        [""J1772""]
# 1  4647 Old Seward Hwy  61.177881 -149.867371        [""TESLA""]
# 2        898 W 5th Ave  61.217229 -149.898855        [""J1772""]
# 3        717 W 3rd Ave  61.219630 -149.895920        [""TESLA""]
# 4  6607 Old Seward Hwy  61.160850 -149.863740        [""J1772""]
#
#    EV_LEVEL1_EVSE_NUM  EV_LEVEL2_EVSE_CNUM  EV_DC_FAST_NUM  ...    Year Month  \
# ...
